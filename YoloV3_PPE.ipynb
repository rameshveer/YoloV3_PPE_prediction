# %% [markdown]
# <a href="https://colab.research.google.com/github/rameshveer/YoloV3_PPE_prediction/blob/master/YoloV3_PPE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rameshveer/YoloV3_PPE_prediction.git
# Out:
# Cloning into 'YoloV3_PPE_prediction'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 6976 (delta 22), reused 24 (delta 8), pack-reused 6926
# Receiving objects: 100% (6976/6976), 257.17 MiB | 48.21 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Checking out files: 100% (7207/7207), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3_PPE_prediction/

# %%
cd YoloV3_PPE_prediction/
# Out:
# /content/YoloV3_PPE_prediction

# %%
# !mv data/customdata/Images data/customdata/images
# !mv data/customdata/Labels data/customdata/labels

# %%
# !ls
# Out:
#  cfg	     output	    runs      'ubdivisions=1'
#  data	     __pycache__    test.py    utils
#  detect.py   results.json   ting       vim.exe.stackdump
#  models.py   results.png    train.py   weights

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 300
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-25 11:29:17.066448: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2863 found, 131 missing, 38 empty, 0 duplicate, for 3032 images): 100% 3032/3032 [00:00<00:00, 9045.78it/s]
# Caching images (1.7GB): 100% 3032/3032 [00:18<00:00, 162.59it/s]
# ...

# %%
# !python3.6 detect.py --source "data/customdata/images/Mimg_044.jpg" --conf-thres 0.1 --output output
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='data/customdata/images/Mimg_044.jpg', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/1 data/customdata/images/Mimg_044.jpg: 512x320 1 hardhats, 1 vests, 1 masks, 2 bootss, Done. (0.035s)
# Results saved to /content/YoloV3_PPE_prediction/output
# Done. (0.099s)

# %%
Image(filename='output/a27.jpg', width=600)

# %%
Image(filename='output/majdoor_211.jpg', width=600)

# %%
Image(filename='output/Mimg_044.jpg', width=600)
